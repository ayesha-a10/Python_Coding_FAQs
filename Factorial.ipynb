# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha-a10/Python_Coding_FAQs/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
  if n<0:
    return "Factorial is not defined for negative numbers."
  elif n==0:
    return 1
  else:
    a=1
    for i in range(1,n+1):
      a*=i
    return a

factorial(9)
# Out:
# 362880
