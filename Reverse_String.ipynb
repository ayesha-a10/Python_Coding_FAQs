# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha-a10/Python_Coding_FAQs/blob/main/Reverse_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse_string(s):
  a=""
  for i in s:
    a=i+a
  return a

reverse_string("applause")
# Out:
# 'esualppa'
